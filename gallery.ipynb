# %%
from plywood_gallery import ChapterConfig

ChapterConfig.clean_all(skip_warning=True)
ChapterConfig.generate_json()
ChapterConfig.set_chapter_name("Pathlib - Elements")


import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 70  


cell_header = '-p Header1.png --celltype Header  --style "width: 600px; height: auto; display:block"'
cell_normal_long =' -p NormalLong.png --celltype Normal  --style "width: 600px; height: auto; display:block"'
cell_normal = '-p Normal.png  --celltype Normal --style "width: 70px; height: auto;"'
# Out:
# Plywood Gallery v0.0.9
# This path and all its child elements will be removed:/Users/jan-hendrik/projects/all_plywood_galleries/plywood-gallery-pathlib/gallery_assets
# Deleted '/Users/jan-hendrik/projects/all_plywood_galleries/plywood-gallery-pathlib/gallery_assets' and all containing files and folder.
# Successfully created /Users/jan-hendrik/projects/all_plywood_galleries/plywood-gallery-pathlib/gallery_assets/gallery_parameters.json!🦫

# %%
# %%capture_png $cell_header
# from pathlib import Path
# mypath = Path("/usr/okapi/projects/plywood_gallery/README.md")
#
# import matplotlib.pyplot as plt  # NOT
# fix, ax = plt.subplots(figsize=(20, 1), facecolor="#F7F5F3");  # NOT
# text_kwargs = dict(ha="center", va="center", fontsize=70, color="#ED6A5A");  # NOT
# ax.text(0.5, 0.5, "Header", **text_kwargs);  # NOT
# ax.axis("off");  # NOT
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
import matplotlib

b = matplotlib.colors.to_hex("royalblue")
g = matplotlib.colors.to_hex("lightgrey")


def rainbow_text(x, y, strings, colors, orientation="horizontal", ax=None, **kwargs):
    if ax is None:
        ax = plt.gca()
    t = ax.transData
    canvas = ax.figure.canvas
    for s, c in zip(strings, colors):
        text = ax.text(x, y, s, color=c, transform=t, **kwargs)
        text.draw(canvas.get_renderer())
        ex = text.get_window_extent()
        if orientation == "horizontal":
            t = text.get_transform() + Affine2D().translate(ex.width, 0)


words = str(mypath)
words = words.replace("/", " / ")
words = words.replace(".", " . ")
words = words.split()
print(words)
colors = ["red","orange","gold","lawngreen","lightseagreen","royalblue","blueviolet","red"]*2

def plot_text(words, colors):
    fig, ax = plt.subplots(figsize=(18, 1), facecolor="#F7F5F3")
    rainbow_text(0.01, 0.2, words, colors, size=40)
    ax.axis("off")


plot_text(words, colors)
# Out:
# ['/', 'usr', '/', 'okapi', '/', 'projects', '/', 'plywood_gallery', '/', 'README', '.', 'md']

# %%
# %%capture_png $cell_normal_long
# colors = [b, g, g, g, g, g, g, g, g, g, g, g] # NOT
# plot_text(words, colors)  # NOT
# mypath.anchor
# Out:
# '/'

# %%
# %%capture_png $cell_normal_long
# colors = [b, b, b, b , g, g, g, g, g, g, g, g] # NOT
# plot_text(words, colors)  # NOT
# str(mypath.parents[2])
# Out:
# '/usr/okapi'

# %%
# %%capture_png $cell_normal_long
# colors = [b, b, b, b, b, b, b, b, g, g, g, g] # NOT
# plot_text(words, colors)  # NOT
# str(mypath.parent)
# Out:
# '/usr/okapi/projects/plywood_gallery'

# %%
# %%capture_png $cell_normal_long
# colors = [b, b, b, b, b, b, b, b, b, b, b, b] # NOT
# plot_text(words, colors)  # NOT
# str(mypath.absolute())
# Out:
# '/usr/okapi/projects/plywood_gallery/README.md'

# %%
# %%capture_png $cell_normal_long
# colors = [g, g, g, g, g, b, b, b, b, b, b, b] # NOT
# plot_text(words, colors)  # NOT
# str(mypath.relative_to(mypath.parents[2]))
# Out:
# 'projects/plywood_gallery/README.md'

# %%
# %%capture_png $cell_normal_long
# colors = [g, g, g, g, g, g, g, b, b, b, b, b] # NOT
# plot_text(words, colors)  # NOT
# str(mypath.relative_to(mypath.parents[1]))
# Out:
# 'plywood_gallery/README.md'

# %%
# %%capture_png $cell_normal_long
# colors = [g, g, g, g, g, g, g, b, g, g, g, g] # NOT
# plot_text(words, colors)  # NOT
# mypath.parts[-2]
# Out:
# 'plywood_gallery'

# %%
# %%capture_png $cell_normal_long
# colors = [g, g, g, g, g, g, g, g, g, b, b, b] # NOT
# plot_text(words, colors)  # NOT
# mypath.name
# Out:
# 'README.md'

# %%
# %%capture_png $cell_normal_long
# colors = [g, g, g, g, g, g, g, g, g, b, g, g] # NOT
# plot_text(words, colors)  # NOT
# mypath.stem
# Out:
# 'README'

# %%
# %%capture_png $cell_normal_long
# colors = [g, g, g, g, g, g, g, g, g, g, b, b] # NOT
# plot_text(words, colors)  # NOT
# mypath.suffix
# Out:
# '.md'

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

from PIL import Image
import numpy as np
import urllib.request
from pathlib import Path

# %%
ChapterConfig.set_chapter_name("Pathlib -  Further Functions")

#get apple emoji
def get_apple_emoji(emoji):
    emoji_code = "-".join(f"{ord(c):x}" for c in emoji)
    url = f"https://raw.githubusercontent.com/cj1128/emoji-images/master/imgs/{emoji_code}.png"
    im = Image.open(requests.get(url, stream=True).raw)
    #im = np.array(im.convert("RGBA"))
    return im


def plot_apple_emojis(e1, e2, overlap =0.5):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    im_e1 = get_apple_emoji(e1)
    im_e2 = get_apple_emoji(e2)

    ax1.imshow(im_e1)
    ax1.axis("off")
    ax2.imshow(im_e2)
    ax2.axis("off")
    plt.subplots_adjust(wspace=-overlap)

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "new_folder"
# path.mkdir()
#
# plot_apple_emojis("📁","➕" ) # NOT

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "new_folder"
# path.rmdir()
#
# plot_apple_emojis("📁","🗑️", overlap=0.4) # NOT

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "new_folder"
# if path.exists():
#     print("File is there")
# else:
#     print("File is not there")
#
# plot_apple_emojis("📁","❓" ) # NOT
# Out:
# File is not there

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "gallery_assets"
#
# for p in path.iterdir():
#     print(p.name)
#
# plot_apple_emojis("📂","📶" ) # NOT
# Out:
# Pathlib_-_Elements_006_NormalLong.png
# Pathlib_-__Further_Functions_013_Normal.png
# Pathlib_-_Elements_009_NormalLong.png
# Pathlib_-_Elements_008_NormalLong.png
# Pathlib_-_Elements_007_NormalLong.png
# Pathlib_-_Elements_005_NormalLong.png
# Pathlib_-_Elements_010_NormalLong.png
# Pathlib_-_Elements_002_NormalLong.png
# Pathlib_-_Elements_003_NormalLong.png
# Pathlib_-_Elements_001_Header1.png
# Pathlib_-__Further_Functions_014_Normal.png
# Pathlib_-_Elements_011_NormalLong.png
# Pathlib_-_Elements_004_NormalLong.png
# Pathlib_-__Further_Functions_012_Normal.png
# gallery_parameters.json

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "foo.txt"
# path.touch()
# plot_apple_emojis("📄","➕" ) # NOT

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "foo.txt"
# path.write_text("Hello World")
# plot_apple_emojis("📄","🖊️" ) # NOT

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "foo.txt"
# size = path.stat().st_size
# print("File size is {size} byte")
# plot_apple_emojis("💾","📟" ) # NOT 💾 󠀥󠀥
# Out:
# File size is {size} byte

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "foo.txt"
# text  = path.read_text()
# print(text)
# plot_apple_emojis("📄","👁️" ) # NOT
# Out:
# Hello World

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "foo.txt"
# path2 = Path.cwd() / "bar.txt"
# path.rename(path2)
# plot_apple_emojis("📄","♻️" ) # NOT

# %%
# %%capture_png $cell_normal
# path = Path.cwd() / "bar.txt"
# path.unlink()
# plot_apple_emojis("📄","🗑️" ) # NOT
