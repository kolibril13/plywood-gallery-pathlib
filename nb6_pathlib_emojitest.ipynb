# %%
from plywood_gallery import ChapterConfig

ChapterConfig.set_assets_folder_name("gallery_assets_6_Pathlib")
ChapterConfig.clean_all(skip_warning=True)
ChapterConfig.generate_json()
ChapterConfig.set_chapter_name("Pathlib - Openmoji")

import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 70
# Out:
# Plywood Gallery v0.0.3
# Sucessfully created /Users/jan-hendrik/projects/further_ideas_plywood_gallery/gallery_assets_6_Pathlib/gallery_parameters.json!🦫
# This path and all its child elements will be removed:/Users/jan-hendrik/projects/further_ideas_plywood_gallery/gallery_assets_6_Pathlib
# Sucessfully created /Users/jan-hendrik/projects/further_ideas_plywood_gallery/gallery_assets_6_Pathlib/gallery_parameters.json!🦫

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

from PIL import Image
import numpy as np
import urllib.request
from pathlib import Path

import zipfile

path_emojis = Path.cwd() / f"temp_emojis"
# get openmoji version 13.1.0
if not path_emojis.exists():  # Download and unzip assets
    path_zip = Path.cwd() / f"openmoji-618x618-color.zip"
    url = f"https://github.com/hfg-gmuend/openmoji/releases/download/13.1.0/openmoji-618x618-color.zip"
    urllib.request.urlretrieve(url, path_zip)
    with zipfile.ZipFile(path_zip, "r") as zip_ref:
        zip_ref.extractall("temp_emojis")
    path_zip.unlink()


def get_open_emoji(emoji):

    emoji_code = "-".join(f"{ord(c):x}" for c in emoji)
    im = Image.open(path_emojis / f"{emoji_code}.png")
    # im = np.array(im.convert("RGBA"))
    return im


def plot_open_emojis(e1, e2, overlap=0.5):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    im_e1 = get_open_emoji(e1)
    im_e2 = get_open_emoji(e2)

    ax1.imshow(im_e1)
    ax1.axis("off")
    ax2.imshow(im_e2)
    ax2.axis("off")
    plt.subplots_adjust(wspace=-overlap)

# %%
# %%capture_png -p Header1.png --celltype Header  --style "width: auto; height: 100px;"
# from pathlib import Path
# import matplotlib.pyplot as plt  # NOT
# fix, ax = plt.subplots(figsize=(5, 3), facecolor="#F7F5F3")  # NOT
# text_kwargs = dict(ha="center", va="center", fontsize=70, color="#ED6A5A")  # NOT
# ax.text(0.5, 0.5, "Header", **text_kwargs)  # NOT
# ax.axis("off");  # NOT
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
# path = Path.cwd() / "new_folder"
# path.mkdir()
#
# plot_open_emojis("📁","➕" ) # NOT

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
#
# path = Path.cwd() / "new_folder"
# path.rmdir()
#
# plot_open_emojis("📁","🗑", overlap=0.4) # NOT

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
# path = Path.cwd() / "new_folder"
# if path.exists():
#     print("File is there")
# else:
#     print("File is not there")
#
# plot_open_emojis("📁","❓" ) # NOT
# Out:
# File is not there

# %%
ChapterConfig.set_chapter_name("Pathlib - Apple Emoji")

#get apple emoji
def get_apple_emoji(emoji):
    emoji_code = "-".join(f"{ord(c):x}" for c in emoji)
    url = f"https://raw.githubusercontent.com/cj1128/emoji-images/master/imgs/{emoji_code}.png"
    im = Image.open(requests.get(url, stream=True).raw)
    #im = np.array(im.convert("RGBA"))
    return im


def plot_apple_emojis(e1, e2, overlap =0.5):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    im_e1 = get_emoji(e1)
    im_e2 = get_emoji(e2)

    ax1.imshow(im_e1)
    ax1.axis("off")
    ax2.imshow(im_e2)
    ax2.axis("off")
    plt.subplots_adjust(wspace=-overlap)

# %%
# %%capture_png -p Header1.png --celltype Header  --style "width: auto; height: 100px;"
# from pathlib import Path
# import matplotlib.pyplot as plt  # NOT
# fix, ax = plt.subplots(figsize=(5, 3), facecolor="#F7F5F3")  # NOT
# text_kwargs = dict(ha="center", va="center", fontsize=70, color="#ED6A5A")  # NOT
# ax.text(0.5, 0.5, "Header", **text_kwargs)  # NOT
# ax.axis("off");  # NOT
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
# path = Path.cwd() / "new_folder"
# path.mkdir()
#
# plot_apple_emojis("📁","➕" ) # NOT

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
#
# path = Path.cwd() / "new_folder"
# path.rmdir()
#
# plot_apple_emojis("📁","🗑️", overlap=0.4) # NOT

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
# path = Path.cwd() / "new_folder"
# if path.exists():
#     print("File is there")
# else:
#     print("File is not there")
#
# plot_apple_emojis("📁","❓" ) # NOT
# Out:
# File is not there

# %%
ChapterConfig.set_chapter_name("Pathlib - Twitter Emoji")

#get twitter emoji
def get_emoji(emoji):
    emoji_code = "-".join(f"{ord(c):x}" for c in emoji)
    url = f"https://raw.githubusercontent.com/twitter/twemoji/master/assets/72x72/{emoji_code}.png"
    im = Image.open(requests.get(url, stream=True).raw)
   # image = np.array(im.convert("RGBA"))
    return im

def plot_twitter_emojis(e1, e2, overlap =0.5):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    im_e1 = get_emoji(e1)
    im_e2 = get_emoji(e2)

    ax1.imshow(im_e1)
    ax1.axis("off")
    ax2.imshow(im_e2)
    ax2.axis("off")
    plt.subplots_adjust(wspace=-overlap)

# %%
#from cairosvg import svg2png

#twitter way
emoji = "👩‍⚕️"

# %%
# %%capture_png -p Header1.png --celltype Header  --style "width: auto; height: 100px;"
# from pathlib import Path
# import matplotlib.pyplot as plt  # NOT
# fix, ax = plt.subplots(figsize=(5, 3), facecolor="#F7F5F3")  # NOT
# text_kwargs = dict(ha="center", va="center", fontsize=70, color="#ED6A5A")  # NOT
# ax.text(0.5, 0.5, "Header", **text_kwargs)  # NOT
# ax.axis("off");  # NOT
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
get_emoji("📁")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=72x72 at 0x107AF57C0>

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
# path = Path.cwd() / "new_folder"
# path.mkdir()
#
# plot_twitter_emojis("📁","➕" ) # NOT

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
#
# path = Path.cwd() / "new_folder"
# path.rmdir()
#
# plot_twitter_emojis("📁","🗑", overlap=0.4) # NOT

# %%
# %%capture_png -p Normal.png  --celltype Normal --style "width: auto; height: 100px;"
# path = Path.cwd() / "new_folder"
# if path.exists():
#     print("File is there")
# else:
#     print("File is not there")
#
# plot_twitter_emojis("📁","❓" ) # NOT
# Out:
# File is not there
